# %%
import json
import pandas as pd
import os
import numpy as np
import pandas as pd

# %%
import nhl_tidy_data_advanced as pre_process

# %%
dataset_root_dir = 'data'
all_games_df = pre_process.concatenate_all_games_data(dataset_root_dir)
all_games_df
# Out:
# Processing directory: data
# Processing directory: data/20202021
# Processing directory: data/20202021/R
# Processing directory: data/20202021/P
# Processing directory: data/20192020
# Processing directory: data/20192020/R
# Processing directory: data/20192020/P
# Processing directory: data/20182019
# Processing directory: data/20182019/R
# Processing directory: data/20182019/P
# Processing directory: data/20172018
# Processing directory: data/20172018/R
# Processing directory: data/20172018/P
# Processing directory: data/20162017
# Processing directory: data/20162017/R
# Processing directory: data/20162017/P
#        event_type      gameID gameType                 home  \
# 0            Shot  2020020180        R    New Jersey Devils
# 1            Shot  2020020180        R    New Jersey Devils
# 2            Shot  2020020180        R    New Jersey Devils
# 3            Goal  2020020180        R    New Jersey Devils
# 4            Shot  2020020180        R    New Jersey Devils
# ...           ...         ...      ...                  ...
# 387824       Shot  2016030153        P  Nashville Predators
# 387825       Shot  2016030153        P  Nashville Predators
# 387826       Shot  2016030153        P  Nashville Predators
# 387827       Shot  2016030153        P  Nashville Predators
# 387828       Goal  2016030153        P  Nashville Predators
#
#                       away    season  eventID  gameID_eventID  \
# 0         New York Rangers  20202021       11   2020020180_11
# 1         New York Rangers  20202021       19   2020020180_19
# 2         New York Rangers  20202021       20   2020020180_20
# 3         New York Rangers  20202021       23   2020020180_23
# 4         New York Rangers  20202021       26   2020020180_26
# ...                    ...       ...      ...             ...
# 387824  Chicago Blackhawks  20162017      859  2016030153_859
# 387825  Chicago Blackhawks  20162017      861  2016030153_861
# 387826  Chicago Blackhawks  20162017      864  2016030153_864
# 387827  Chicago Blackhawks  20162017      867  2016030153_867
# 387828  Chicago Blackhawks  20162017      870  2016030153_870
#
#                    game_time  game_period  ...    last_event  \
# 0       2021-03-05T00:10:40Z            1  ...      Takeaway
# 1       2021-03-05T00:14:59Z            1  ...      Giveaway
# 2       2021-03-05T00:16:31Z            1  ...      Giveaway
# 3       2021-03-05T00:19:10Z            1  ...       Faceoff
# 4       2021-03-05T00:20:40Z            1  ...      Takeaway
# ...                      ...          ...  ...           ...
# 387824  2017-04-18T05:01:24Z            4  ...  Blocked Shot
# 387825  2017-04-18T05:03:14Z            4  ...   Missed Shot
# 387826  2017-04-18T05:05:35Z            4  ...       Faceoff
# 387827  2017-04-18T05:06:20Z            4  ...   Missed Shot
# 387828  2017-04-18T05:08:15Z            4  ...      Giveaway
#
#         distance_from_last_event  rebound      speed  power_play_time  \
# 0                      66.287254    False   4.734804                0
# 1                      46.227697    False   4.202518                0
# 2                      53.935146    False   3.172656                0
# 3                      28.160256    False   1.482119                0
# 4                      61.073726    False  15.268431                0
# ...                          ...      ...        ...              ...
# 387824                 55.362442    False   9.227074                0
# 387825                 29.206164    False   0.286335                0
# 387826                 41.677332    False  20.838666                0
# 387827                 75.643903    False   6.303659                0
# 387828                117.038455    False  13.004273                0
#
#        time_since_powerplay_started num_friendly_non_goalie_skaters  \
# 0                                 0                               5
# 1                                 0                               5
# 2                                 0                               5
# 3                                 0                               5
# 4                                 0                               5
# ...                             ...                             ...
# 387824                            0                               5
# 387825                            0                               5
# 387826                            0                               5
# 387827                            0                               5
# 387828                            0                               5
#
#         num_opposing_non_goalie_skaters  is_emptyNet  strength
# 0                                     5          NaN       NaN
# 1                                     5          NaN       NaN
# 2                                     5          NaN       NaN
# 3                                     5        False      Even
# 4                                     5          NaN       NaN
# ...                                 ...          ...       ...
# 387824                                5          NaN       NaN
# 387825                                5          NaN       NaN
# 387826                                5          NaN       NaN
# 387827                                5          NaN       NaN
# 387828                                5        False      Even
#
# [387829 rows x 31 columns]

# %%
all_games_df.to_csv("data/all_game_data_milesstone_2.csv", index=False)

# %% [markdown]
# Add extra features defined in Feat Eng 1

# %%
from feature_engineering import FeatureEngineering

# %%
fe = FeatureEngineering(path_to_tidy_data="data/all_game_data_milesstone_2.csv")

# %%
fe.tranform()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'angle'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /Users/mahmoodhegazy/Desktop/Mila Masters/Courses/IFT 6758 - Data Science/Project/nhl_ds_project/src/tidy_data_milestone2.ipynb Cell 8 line 1
# ----> <a href='vscode-notebook-cell:/Users/mahmoodhegazy/Desktop/Mila%20Masters/Courses/IFT%206758%20-%20Data%20Science/Project/nhl_ds_project/src/tidy_data_milestone2.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> fe.tranform()
#
# File ~/Desktop/Mila Masters/Courses/IFT 6758 - Data Science/Project/nhl_ds_project/src/feature_engineering.py:69, in FeatureEngineering.tranform(self)
#      67 goal_rate = self.df['is_goal'].sum() / len(self.df)
#      68 self.df['goal_rate_dist'] = goal_rate / self.df['shot_distance_to_goal']
# ---> 69 self.df['goal_rate_angle'] = goal_rate / self.df['angle']
#      70 self.df['goal_rate_dist'] = self.df['goal_rate_dist'].replace([math.inf], 1)
#      71 self.df['goal_rate_angle'] = self.df['goal_rate_angle'].replace([-math.inf], 1)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'angle'

# %%
fe.df.to_csv("data/all_game_data_milesstone_2.csv", index=False)
