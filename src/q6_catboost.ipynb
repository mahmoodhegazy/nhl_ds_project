# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import classification_report,confusion_matrix, accuracy_score, f1_score, precision_score, recall_score, PrecisionRecallDisplay, roc_curve, auc
from sklearn.calibration import calibration_curve, CalibrationDisplay
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LinearRegression
from sklearn.neural_network import MLPClassifier
from sklearn.svm import LinearSVC
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.model_selection import cross_validate, GridSearchCV
from sklearn.feature_selection import SelectFromModel, RFE,RFECV
from sklearn.pipeline import Pipeline
import os
import other_ml_models
from comet_ml import Experiment
from comet_ml.integration.sklearn import log_model
from feature_engineering import FeatureEngineering
from catboost import CatBoostClassifier, Pool, metrics, cv
# %matplotlib inline

# %%
pd.set_option('display.max_columns', 500)

# %%
df_train, df_test = FeatureEngineering("data/all_game_data_milesstone_2.csv").train_test_split()

# %% [markdown]
# Split into Train and Validation sets

# %%
train_cols = ['x_coordinate', 'y_coordinate', 'last_x_coordinate',
       'last_y_coordinate', 'distance_from_last_event',
       'rebound', 'speed', 'time_since_powerplay_started',
       'num_friendly_non_goalie_skaters', 'num_opposing_non_goalie_skaters',
       'is_emptyNet', 'shot_type', 'shot_distance_to_goal',
       'shot_angle', 'change_in_shot_angle']

X = df_train[train_cols]
y = df_train["is_goal"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, shuffle=True, random_state=42)

# %% [markdown]
# # CatBosst

# %% [markdown]
# ## Create Pipeline

# %%
os.environ["COMET_API_KEY"] = "h85xbEnyF7lyFkSRYhBshWV8E"

# %%
experiment = Experiment(
  api_key=os.environ.get("COMET_API_KEY"),
  project_name="nhl-data-science",
  workspace="mahmoodhegazy"
)

[experiment.log_dataset_hash(data_set) for data_set in [X_train, X_test, y_train, y_test]]
# Out:
# COMET WARNING: To get all data logged automatically, import comet_ml before the following modules: sklearn.
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/mahmoodhegazy/nhl-data-science/9c6dcd37a29a4840872a3f998ca30570
# [None, None, None, None]

# %%
params = {
    'n_estimators': 'n_estimators',
    'learning_rate': 'learning_rate',
    'max_depth': 'max_depth',
    'min_data_in_leaf': 'min_data_in_leaf',
    'eval_metric': metrics.Accuracy(),
    'random_seed': 42,
    'logging_level': 'Silent',
    'use_best_model': False
}
clf_cat = CatBoostClassifier(**params)
recursive_cv_feature_selection = RFECV( min_features_to_select=1,estimator=LinearRegression())
cat_pipe = other_ml_models.create_pipeline(classifier=clf_cat,feature_selection=recursive_cv_feature_selection)

# %%
cat_pipe
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('Numerical_transform',
#                                                   Pipeline(steps=[('Impt',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x2d9ea7d50>),
#                                                  ('Categorical_transform',
#                                                   Pipeline(steps=[('Impt',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                   unknown_value=-1))]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x2d9ea4490>)])),
#                 ('feature_select', RFECV(estimator=LinearRegression())),
#                 ('classifier',
#                  <catboost.core.CatBoostClassifier object at 0x2d9ea5e10>)])

# %% [markdown]
# ## Grid Search Hyperparamtuning

# %%
param_grid = {'classifier__n_estimators': [100, 300, 500],
                'classifier__learning_rate': [0.1, 0.01],
                'classifier__max_depth': [6, 12, 18],
                'classifier__min_data_in_leaf': [1, 2],
}

# Fit a 3-fold GridSearchCV
cat_gs = GridSearchCV(cat_pipe, param_grid, cv=2, verbose=1, n_jobs=-1)
cat_gs.fit(X_train, y_train)

# Print the best parameters and the corresponding score
print("Best parameters:")
print(cat_gs.best_params_)
print("Grid scores:")
means = cat_gs.cv_results_['mean_test_score']
stds = cat_gs.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, cat_gs.cv_results_['params']):
    print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
# Out:
# Fitting 2 folds for each of 36 candidates, totalling 72 fits
# /Users/mahmoodhegazy/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:700: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /Users/mahmoodhegazy/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:425: FitFailedWarning:
# 24 fits failed out of a total of 72.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 24 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/mahmoodhegazy/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/mahmoodhegazy/anaconda3/lib/python3.11/site-packages/sklearn/base.py", line 1151, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mahmoodhegazy/anaconda3/lib/python3.11/site-packages/sklearn/pipeline.py", line 420, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/Users/mahmoodhegazy/anaconda3/lib/python3.11/site-packages/catboost/core.py", line 5131, in fit
#     self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#   File "/Users/mahmoodhegazy/anaconda3/lib/python3.11/site-packages/catboost/core.py", line 2341, in _fit
#     train_params = self._prepare_train_params(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mahmoodhegazy/anaconda3/lib/python3.11/site-packages/catboost/core.py", line 2268, in _prepare_train_params
#     _check_train_params(params)
#   File "_catboost.pyx", line 6085, in _catboost._check_train_params
#   File "_catboost.pyx", line 6104, in _catboost._check_train_params
# _catboost.CatBoostError: /Users/zomb-ml-platform-msk/go-agent-21.2.0/pipelines/BuildMaster/catboost.git/catboost/private/libs/options/oblivious_tree_options.cpp:125: Maximum tree depth is 16
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/mahmoodhegazy/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_search.py:976: UserWarning: One or more of the test scores are non-finite: [0.92711653 0.92811205 0.92806991 0.92711653 0.92811205 0.92806991
#  0.92785922 0.92717973 0.92624216 0.92785922 0.92717973 0.92624216
#         nan        nan        nan        nan        nan        nan
#  0.91878368 0.92576284 0.92640018 0.91878368 0.92576284 0.92640018
#  0.92537832 0.92659507 0.92728508 0.92537832 0.92659507 0.92728508
#         nan        nan        nan        nan        nan        nan]
#   warnings.warn(
# Best parameters:
# {'classifier__learning_rate': 0.1, 'classifier__max_depth': 6, 'classifier__min_data_in_leaf': 1, 'classifier__n_estimators': 300}
# Grid scores:
# 0.927 (+/-0.001) for {'classifier__learning_rate': 0.1, 'classifier__max_depth': 6, 'classifier__min_data_in_leaf': 1, 'classifier__n_estimators': 100}
# 0.928 (+/-0.000) for {'classifier__learning_rate': 0.1, 'classifier__max_depth': 6, 'classifier__min_data_in_leaf': 1, 'classifier__n_estimators': 300}
# 0.928 (+/-0.000) for {'classifier__learning_rate': 0.1, 'classifier__max_depth': 6, 'classifier__min_data_in_leaf': 1, 'classifier__n_estimators': 500}
# 0.927 (+/-0.001) for {'classifier__learning_rate': 0.1, 'classifier__max_depth': 6, 'classifier__min_data_in_leaf': 2, 'classifier__n_estimators': 100}
# 0.928 (+/-0.000) for {'classifier__learning_rate': 0.1, 'classifier__max_depth': 6, 'classifier__min_data_in_leaf': 2, 'classifier__n_estimators': 300}
# 0.928 (+/-0.000) for {'classifier__learning_rate': 0.1, 'classifier__max_depth': 6, 'classifier__min_data_in_leaf': 2, 'classifier__n_estimators': 500}
# 0.928 (+/-0.001) for {'classifier__learning_rate': 0.1, 'classifier__max_depth': 12, 'classifier__min_data_in_leaf': 1, 'classifier__n_estimators': 100}
# 0.927 (+/-0.000) for {'classifier__learning_rate': 0.1, 'classifier__max_depth': 12, 'classifier__min_data_in_leaf': 1, 'classifier__n_estimators': 300}
# 0.926 (+/-0.000) for {'classifier__learning_rate': 0.1, 'classifier__max_depth': 12, 'classifier__min_data_in_leaf': 1, 'classifier__n_estimators': 500}
# 0.928 (+/-0.001) for {'classifier__learning_rate': 0.1, 'classifier__max_depth': 12, 'classifier__min_data_in_leaf': 2, 'classifier__n_estimators': 100}
# 0.927 (+/-0.000) for {'classifier__learning_rate': 0.1, 'classifier__max_depth': 12, 'classifier__min_data_in_leaf': 2, 'classifier__n_estimators': 300}
# 0.926 (+/-0.000) for {'classifier__learning_rate': 0.1, 'classifier__max_depth': 12, 'classifier__min_data_in_leaf': 2, 'classifier__n_estimators': 500}
# nan (+/-nan) for {'classifier__learning_rate': 0.1, 'classifier__max_depth': 18, 'classifier__min_data_in_leaf': 1, 'classifier__n_estimators': 100}
# nan (+/-nan) for {'classifier__learning_rate': 0.1, 'classifier__max_depth': 18, 'classifier__min_data_in_leaf': 1, 'classifier__n_estimators': 300}
# nan (+/-nan) for {'classifier__learning_rate': 0.1, 'classifier__max_depth': 18, 'classifier__min_data_in_leaf': 1, 'classifier__n_estimators': 500}
# nan (+/-nan) for {'classifier__learning_rate': 0.1, 'classifier__max_depth': 18, 'classifier__min_data_in_leaf': 2, 'classifier__n_estimators': 100}
# nan (+/-nan) for {'classifier__learning_rate': 0.1, 'classifier__max_depth': 18, 'classifier__min_data_in_leaf': 2, 'classifier__n_estimators': 300}
# nan (+/-nan) for {'classifier__learning_rate': 0.1, 'classifier__max_depth': 18, 'classifier__min_data_in_leaf': 2, 'classifier__n_estimators': 500}
# 0.919 (+/-0.002) for {'classifier__learning_rate': 0.01, 'classifier__max_depth': 6, 'classifier__min_data_in_leaf': 1, 'classifier__n_estimators': 100}
# 0.926 (+/-0.001) for {'classifier__learning_rate': 0.01, 'classifier__max_depth': 6, 'classifier__min_data_in_leaf': 1, 'classifier__n_estimators': 300}
# 0.926 (+/-0.001) for {'classifier__learning_rate': 0.01, 'classifier__max_depth': 6, 'classifier__min_data_in_leaf': 1, 'classifier__n_estimators': 500}
# 0.919 (+/-0.002) for {'classifier__learning_rate': 0.01, 'classifier__max_depth': 6, 'classifier__min_data_in_leaf': 2, 'classifier__n_estimators': 100}
# 0.926 (+/-0.001) for {'classifier__learning_rate': 0.01, 'classifier__max_depth': 6, 'classifier__min_data_in_leaf': 2, 'classifier__n_estimators': 300}
# 0.926 (+/-0.001) for {'classifier__learning_rate': 0.01, 'classifier__max_depth': 6, 'classifier__min_data_in_leaf': 2, 'classifier__n_estimators': 500}
# 0.925 (+/-0.000) for {'classifier__learning_rate': 0.01, 'classifier__max_depth': 12, 'classifier__min_data_in_leaf': 1, 'classifier__n_estimators': 100}
# 0.927 (+/-0.001) for {'classifier__learning_rate': 0.01, 'classifier__max_depth': 12, 'classifier__min_data_in_leaf': 1, 'classifier__n_estimators': 300}
# 0.927 (+/-0.001) for {'classifier__learning_rate': 0.01, 'classifier__max_depth': 12, 'classifier__min_data_in_leaf': 1, 'classifier__n_estimators': 500}
# 0.925 (+/-0.000) for {'classifier__learning_rate': 0.01, 'classifier__max_depth': 12, 'classifier__min_data_in_leaf': 2, 'classifier__n_estimators': 100}
# 0.927 (+/-0.001) for {'classifier__learning_rate': 0.01, 'classifier__max_depth': 12, 'classifier__min_data_in_leaf': 2, 'classifier__n_estimators': 300}
# 0.927 (+/-0.001) for {'classifier__learning_rate': 0.01, 'classifier__max_depth': 12, 'classifier__min_data_in_leaf': 2, 'classifier__n_estimators': 500}
# nan (+/-nan) for {'classifier__learning_rate': 0.01, 'classifier__max_depth': 18, 'classifier__min_data_in_leaf': 1, 'classifier__n_estimators': 100}
# nan (+/-nan) for {'classifier__learning_rate': 0.01, 'classifier__max_depth': 18, 'classifier__min_data_in_leaf': 1, 'classifier__n_estimators': 300}
# nan (+/-nan) for {'classifier__learning_rate': 0.01, 'classifier__max_depth': 18, 'classifier__min_data_in_leaf': 1, 'classifier__n_estimators': 500}
# nan (+/-nan) for {'classifier__learning_rate': 0.01, 'classifier__max_depth': 18, 'classifier__min_data_in_leaf': 2, 'classifier__n_estimators': 100}
# nan (+/-nan) for {'classifier__learning_rate': 0.01, 'classifier__max_depth': 18, 'classifier__min_data_in_leaf': 2, 'classifier__n_estimators': 300}
# nan (+/-nan) for {'classifier__learning_rate': 0.01, 'classifier__max_depth': 18, 'classifier__min_data_in_leaf': 2, 'classifier__n_estimators': 500}

# %% [markdown]
# Train on best Hyperparams

# %%
cat_pipe_best = cat_gs.best_estimator_
cat_pipe_best.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('Numerical_transform',
#                                                   Pipeline(steps=[('Impt',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x28ee78a50>),
#                                                  ('Categorical_transform',
#                                                   Pipeline(steps=[('Impt',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                   unknown_value=-1))]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x2dacc0ed0>)])),
#                 ('feature_select', RFECV(estimator=LinearRegression())),
#                 ('classifier',
#                  <catboost.core.CatBoostClassifier object at 0x2dacc2ed0>)])

# %% [markdown]
# ## Logging Validation Scores

# %%
preds = cat_pipe_best.predict(X_test)
preds_train = cat_pipe_best.predict(X_train)

print("Accuracy (train): ", accuracy_score(y_train,preds_train))
print("Accuracy (test): ", accuracy_score(y_test,preds))
print("Classification report:\n", classification_report(y_test,preds))
# Out:
# Accuracy (train):  0.9302927032251608
# Accuracy (test):  0.9315888165518403
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96     43126
#            1       0.87      0.29      0.44      4337
#
#     accuracy                           0.93     47463
#    macro avg       0.90      0.65      0.70     47463
# weighted avg       0.93      0.93      0.92     47463

# %%
preds_prob = cat_pipe_best.predict_proba(X_test)

# %%
cm=confusion_matrix(y_test, preds)
sns.heatmap(cm, annot=True,fmt="d")
experiment.log_figure(figure_name='Confusion Matrix', step=None)
# Out:
# {'web': 'https://www.comet.com/api/image/download?imageId=29fda39129b1415b921d85aaffef2103&experimentKey=9c6dcd37a29a4840872a3f998ca30570',
#  'api': 'https://www.comet.com/api/rest/v1/image/get-image?imageId=29fda39129b1415b921d85aaffef2103&experimentKey=9c6dcd37a29a4840872a3f998ca30570',
#  'imageId': '29fda39129b1415b921d85aaffef2103'}

# %%
metrics = {"accuracy": accuracy_score(y_test, preds), "f1": f1_score(y_test, preds), "recall": recall_score(y_test, preds), "precision": precision_score(y_test, preds)}
parameter = {
    "model_type": 'Catboost',
    "param_grid": str(cat_pipe_best.get_params()),
}
experiment.log_parameters(parameter)
experiment.log_metrics(metrics)
# Out:
# COMET WARNING: truncated string; too long: '{'memory': None, 'steps': [('preprocessor', ColumnTransformer(transformers=[('Numerical_transform',
#                                  Pipeline(steps=[('Impt', SimpleImputer()),
#                                                  ('scaler', StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x28ee78a50>),
#                                 ('Categorical_transform',
#                                  Pipeline(steps=[('Impt',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('encoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x2dacc0ed0>)])), ('feature_select', RFECV(estimator=LinearRegression())), ('classifier', <catboost.core.CatBoostClassifier object at 0x2dacc2ed0>)], 'verbose': False, 'preprocessor': ColumnTransformer(transformers=[('Numerical_transform',
#                                  Pipeline(steps=[('Impt', SimpleImputer()),
#                                                  ('scaler', StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x28ee78a50>),
#                                 ('Categorical_transform',
#                                  Pipeline(steps=[('Impt',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('encoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x2dacc0ed0>)]), 'feature_select': RFECV(estimator=LinearRegression()), 'classifier': <catboost.core.CatBoostClassifier object at 0x2dacc2ed0>, 'preprocessor__n_jobs': None, 'preprocessor__remainder': 'drop', 'preprocessor__sparse_threshold': 0.3, 'preprocessor__transformer_weights': None, 'preprocessor__transformers': [('Numerical_transform', Pipeline(steps=[('Impt', SimpleImputer()), ('scaler', StandardScaler())]), <sklearn.compose._column_transformer.make_column_selector object at 0x28ee78a50>), ('Categorical_transform', Pipeline(steps=[('Impt', SimpleImputer(strategy='most_frequent')),
#                 ('encoder',
#                  OrdinalEncoder(handle_unknown='use_encoded_value',
#                                 unknown_value=-1))]), <sklearn.compose._column_transformer.make_column_selector object at 0x2dacc0ed0>)], 'preprocessor__verbose': False, 'preprocessor__verbose_feature_names_out': True, 'preprocessor__Numerical_transform': Pipeline(steps=[('Impt', SimpleImputer()), ('scaler', StandardScaler())]), 'preprocessor__Categorical_transform': Pipeline(steps=[('Impt', SimpleImputer(strategy='most_frequent')),
#                 ('encoder',
#                  OrdinalEncoder(handle_unknown='use_encoded_value',
#                                 unknown_value=-1))]), 'preprocessor__Numerical_transform__memory': None, 'preprocessor__Numerical_transform__steps': [('Impt', SimpleImputer()), ('scaler', StandardScaler())], 'preprocessor__Numerical_transform__verbose': False, 'preprocessor__Numerical_transform__Impt': SimpleImputer(), 'preprocessor__Numerical_transform__scaler': StandardScaler(), 'preprocessor__Numerical_transform__Impt__add_indicator': False, 'preprocessor__Numerical_transform__Impt__copy': True, 'preprocessor__Numerical_transform__Impt__fill_value': None, 'preprocessor__Numerical_transform__Impt__keep_empty_features': False, 'preprocessor__Numerical_transform__Impt__missing_values': nan, 'preprocessor__Numerical_transform__Impt__strategy': 'mean', 'preprocessor__Numerical_transform__scaler__copy': True, 'preprocessor__Numerical_transform__scaler__with_mean': True, 'preprocessor__Numerical_transform__scaler__with_std': True, 'preprocessor__Categorical_transform__memory': None, 'preprocessor__Categorical_transform__steps': [('Impt', SimpleImputer(strategy='most_frequent')), ('encoder', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1))], 'preprocessor__Categorical_transform__verbose': False, 'preprocessor__Categorical_transform__Impt': SimpleImputer(strategy='most_frequent'), 'preprocessor__Categorical_transform__encoder': OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1), 'preprocessor__Categorical_transform__Impt__add_indicator': False, 'preprocessor__Categorical_transform__Impt__copy': True, 'preprocessor__Categorical_transform__Impt__fill_value': None, 'preprocessor__Categorical_transform__Impt__keep_empty_features': False, 'preprocessor__Categorical_transform__Impt__missing_values': nan, 'preprocessor__Categorical_transform__Impt__strategy': 'most_frequent', 'preprocessor__Categorical_transform__encoder__categories': 'auto', 'preprocessor__Categorical_transform__encoder__dtype': <class 'numpy.float64'>, 'preprocessor__Categorical_transform__encoder__encoded_missing_value': nan, 'preprocessor__Categorical_transform__encoder__handle_unknown': 'use_encoded_value', 'preprocessor__Categorical_transform__encoder__max_categories': None, 'preprocessor__Categorical_transform__encoder__min_frequency': None, 'preprocessor__Categorical_transform__encoder__unknown_value': -1, 'feature_select__cv': None, 'feature_select__estimator__copy_X': True, 'feature_select__estimator__fit_intercept': True, 'feature_select__estimator__n_jobs': None, 'feature_select__estimator__positive': False, 'feature_select__estimator': LinearRegression(), 'feature_select__importance_getter': 'auto', 'feature_select__min_features_to_select': 1, 'feature_select__n_jobs': None, 'feature_select__scoring': None, 'feature_select__step': 1, 'feature_select__verbose': 0, 'classifier__learning_rate': 0.1, 'classifier__random_seed': 42, 'classifier__use_best_model': False, 'classifier__logging_level': 'Silent', 'classifier__eval_metric': 'Accuracy', 'classifier__max_depth': 6, 'classifier__n_estimators': 300, 'classifier__min_data_in_leaf': 1}'...

# %% [markdown]
# ### Prec-Recall Curve

# %%
other_ml_models.plot_precision_recall(model=cat_pipe_best, X_test=X_test, y_test=y_test, experiment=experiment)

# %% [markdown]
# ### ROC Curve

# %%
plt.figure(figsize=(10, 6))
line_width = 2

false_positive_rate, true_positive_rate, _ = roc_curve(y_test.ravel(),preds_prob[:,1].ravel())
area_under_curve = auc(false_positive_rate, true_positive_rate)
plt.plot(false_positive_rate, true_positive_rate, lw=line_width, label=f"Model Catboost - AUC: {area_under_curve:.2f}")

plt.plot([0, 1], [0, 1], color="grey", lw=line_width, linestyle='--', label="Baseline (Random)")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve Comparison")
plt.legend(loc="lower right")
experiment.log_figure(figure_name='ROC-AUC', step=None)
plt.show()

# %% [markdown]
# ### Goal Rate Plot

# %%
bins = list(np.arange(0, 105,  5))
bin_centers = list(np.arange(2.5, 100,  5.0))
df_prob = pd.DataFrame(list(zip(preds ,y_test ,preds_prob[:,1]*100)), columns = ['goal_pred', 'goal','goal_probability'])
df_prob['shot'] = 1
sum_goal = df_prob['goal'].sum()
df_prob['percentile'] = df_prob['goal_probability'].rank(pct=True) * 100
df_prob['goal_perc_bins'] = pd.cut(df_prob['percentile'], bins, labels = bin_centers)
df_prob_bined = df_prob[['goal_perc_bins', 'shot', 'goal' ]].groupby(['goal_perc_bins']).sum().reset_index()
df_prob_bined['goal_rate'] = (df_prob_bined['goal']/df_prob_bined['shot'])
df_prob_bined['goal_cum'] = (df_prob_bined['goal']/sum_goal)
df_prob_bined['goal_cumsum'] = 1-df_prob_bined['goal_cum'].cumsum()

# %%
other_ml_models.generate_goal_rate_plot("Catboost", df_prob_bined, experiment)

# %% [markdown]
# ### Cumulative Goal Analysis

# %%
other_ml_models.visualize_cumulative_goals("Catboost", df_prob_bined, experiment)

# %% [markdown]
# ### Calibration curve

# %%
other_ml_models.plot_calibration_curve(y_test, preds_prob, experiment)

# %% [markdown]
# ### Save Model

# %%
import pickle

# %%
if not os.path.exists('models/'):
    os.mkdir('models/')
    
pickle.dump(cat_pipe_best, open('models/cat_boost.sav', 'wb'))
experiment.log_model("Cat Boost Clf", 'models/cat_boost.sav')
# Out:
# {'web': 'https://www.comet.com/api/asset/download?assetId=8bdeed09ad034da79bff5335d098b065&experimentKey=9c6dcd37a29a4840872a3f998ca30570',
#  'api': 'https://www.comet.com/api/rest/v2/experiment/asset/get-asset?assetId=8bdeed09ad034da79bff5335d098b065&experimentKey=9c6dcd37a29a4840872a3f998ca30570',
#  'assetId': '8bdeed09ad034da79bff5335d098b065'}

# %%
experiment.end()
# Out:
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.com/mahmoodhegazy/nhl-data-science/9c6dcd37a29a4840872a3f998ca30570
# COMET INFO:   Metrics:
# COMET INFO:     accuracy  : 0.9315888165518403
# COMET INFO:     f1        : 0.4402689191518704
# COMET INFO:     precision : 0.8722677595628415
# COMET INFO:     recall    : 0.2944431634770579
# COMET INFO:   Parameters:
# COMET INFO:     model_type : Catboost
# COMET INFO:     param_grid : {'memory': None, 'steps': [('preprocessor', ColumnTransformer(transformers=[('Numerical_transform',
#                                  Pipeline(steps=[('Impt', SimpleImputer()),
#                                                  ('scaler', StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x28ee78a50>),
#                                 ('Categorical_transform',
#                                  Pipeline(steps=[('Impt',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('encoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x2dacc0ed0>)])), ('feature_select', RFECV(estimator=Line [truncated]
# COMET INFO:   Uploads:
# COMET INFO:     conda-environment-definition : 1
# COMET INFO:     conda-info                   : 1
# COMET INFO:     conda-specification          : 1
# COMET INFO:     environment details          : 1
# COMET INFO:     figures                      : 6
# COMET INFO:     filename                     : 1
# COMET INFO:     git metadata                 : 1
# COMET INFO:     git-patch (uncompressed)     : 1 (262 bytes)
# COMET INFO:     installed packages           : 1
# COMET INFO:     model-element                : 1 (331.11 KB)
# COMET INFO:     notebook                     : 1
# COMET INFO:     source_code                  : 1
# COMET INFO:
# COMET WARNING: To get all data logged automatically, import comet_ml before the following modules: sklearn.
