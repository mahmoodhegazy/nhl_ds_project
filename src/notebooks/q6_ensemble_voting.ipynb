# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import classification_report,confusion_matrix, accuracy_score, f1_score, precision_score, recall_score, PrecisionRecallDisplay, roc_curve, auc
from sklearn.calibration import calibration_curve, CalibrationDisplay
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LinearRegression
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.svm import LinearSVC
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.model_selection import cross_validate, GridSearchCV
from sklearn.feature_selection import SelectFromModel, RFE,RFECV
from sklearn.pipeline import Pipeline
import os
import other_ml_models
from comet_ml import Experiment
from comet_ml.integration.sklearn import log_model
from feature_engineering import FeatureEngineering
from catboost import CatBoostClassifier, Pool, metrics, cv
# %matplotlib inline

# %%
pd.set_option('display.max_columns', 500)

# %%
df_train, df_test = FeatureEngineering("data/all_game_data_milesstone_2.csv").train_test_split()

# %% [markdown]
# Split into Train and Validation sets

# %%
train_cols = ['x_coordinate', 'y_coordinate', 'last_x_coordinate',
       'last_y_coordinate', 'distance_from_last_event', 'last_event',
       'rebound', 'speed', 'time_since_powerplay_started',
       'num_friendly_non_goalie_skaters', 'num_opposing_non_goalie_skaters',
       'is_emptyNet', 'shot_type', 'shot_distance_to_goal',
       'shot_angle', 'change_in_shot_angle']

X = df_train[train_cols]
X.rebound = X.rebound.astype(int)
df_test.rebound = df_test.rebound.astype(int)
y = df_train["is_goal"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, shuffle=True, random_state=42)
# Out:
# /var/folders/47/th8gfrqd2k977395fgq4b6vh0000gn/T/ipykernel_84708/2070492032.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.rebound = X.rebound.astype(int)

# %% [markdown]
# # Ensemble Voting Clf

# %% [markdown]
# ## Create Pipeline

# %%
experiment = Experiment(
  api_key=os.environ.get("COMET_API_KEY"),
  project_name="nhl-data-science",
  workspace="mahmoodhegazy"
)

[experiment.log_dataset_hash(data_set) for data_set in [X_train, X_test, y_train, y_test]]
# Out:
# COMET WARNING: To get all data logged automatically, import comet_ml before the following modules: sklearn.
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/mahmoodhegazy/nhl-data-science/78e64bfdfe2542b3972670db94f52bf2
# [None, None, None, None]

# %%
## Best KNN 
best_knn_params = {'algorithm': 'auto', 'metric': 'euclidean', 'n_neighbors': 11, 'weights': 'uniform'}
knn_clf=KNeighborsClassifier(**best_knn_params)
recursive_cv_feature_selection = RFECV( min_features_to_select=1,estimator=LinearRegression())
knn_best_pipe = other_ml_models.create_pipeline(classifier=knn_clf,feature_selection=recursive_cv_feature_selection)

## Best MLP
best_mlp_params = {'activation': 'tanh', 'alpha': 0.01, 'hidden_layer_sizes': (50, 100, 100, 50), 'learning_rate': 'constant', 'solver': 'adam'}
mlp_clf=MLPClassifier(**best_mlp_params, early_stopping=True, n_iter_no_change=10, random_state=42)
feature_selection_svc= SelectFromModel(estimator=LinearSVC(C=0.1, dual="auto"))
mlp_best_pipe = other_ml_models.create_pipeline(classifier=mlp_clf,feature_selection=feature_selection_svc)

## Best RF
best_rf_params = {'max_depth': 20, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 100}
rf_clf= RandomForestClassifier(**best_rf_params, random_state=42)
recursive_cv_feature_selection = RFECV( min_features_to_select=1,estimator=LinearRegression())
rf_best_pipe = other_ml_models.create_pipeline(classifier=rf_clf,feature_selection=recursive_cv_feature_selection)

## Best RF Balanced
best_rf_balanced_params = {'max_depth': 60, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 80}
rf_balanced_clf= RandomForestClassifier(**best_rf_balanced_params, random_state=42)
recursive_cv_feature_selection = RFECV( min_features_to_select=1,estimator=LinearRegression())
rf_balanced_best_pipe = other_ml_models.create_pipeline(classifier=rf_balanced_clf,feature_selection=recursive_cv_feature_selection)

## Best Catboost
best_cat_params = {
    'n_estimators': 500,
    'learning_rate': 0.1,
    'eval_metric': metrics.Accuracy(),
    'random_seed': 42,
    'logging_level': 'Silent',
    'use_best_model': False
}
cat_clf= CatBoostClassifier(**best_cat_params)
recursive_cv_feature_selection = RFECV( min_features_to_select=1,estimator=LinearRegression())
cat_best_pipe = other_ml_models.create_pipeline(classifier=cat_clf,feature_selection=recursive_cv_feature_selection)

# %%
vc = VotingClassifier(estimators=[('random_forest',rf_best_pipe),('random_forest_balanced',rf_balanced_best_pipe),('cat_boost_clf',cat_best_pipe),('mlp',mlp_best_pipe), ('KNN', knn_best_pipe)], 
                      voting='soft')
vc.fit(X_train, y_train)
# Out:
# VotingClassifier(estimators=[('random_forest',
#                               Pipeline(steps=[('preprocessor',
#                                                ColumnTransformer(transformers=[('Numerical_transform',
#                                                                                 Pipeline(steps=[('Impt',
#                                                                                                  SimpleImputer()),
#                                                                                                 ('scaler',
#                                                                                                  StandardScaler())]),
#                                                                                 <sklearn.compose._column_transformer.make_column_selector object at 0x172fd6110>),
#                                                                                ('Categorical_transform',
#                                                                                 Pipeline(steps=[('Impt',
#                                                                                                  SimpleImputer(stra...
#                                                                                 Pipeline(steps=[('Impt',
#                                                                                                  SimpleImputer(strategy='most_frequent')),
#                                                                                                 ('encoder',
#                                                                                                  OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                                                 unknown_value=-1))]),
#                                                                                 <sklearn.compose._column_transformer.make_column_selector object at 0x172fd6810>)])),
#                                               ('feature_select',
#                                                RFECV(estimator=LinearRegression())),
#                                               ('classifier',
#                                                KNeighborsClassifier(metric='euclidean',
#                                                                     n_neighbors=11))]))],
#                  voting='soft')

# %% [markdown]
# ## Logging Validation Scores

# %%
preds = vc.predict(X_test)
preds_train = vc.predict(X_train)

print("Accuracy (train): ", accuracy_score(y_train,preds_train))
print("Accuracy (test): ", accuracy_score(y_test,preds))
print("Classification report:\n", classification_report(y_test,preds))
# Out:
# Accuracy (train):  0.9460998361873258
# Accuracy (test):  0.9461685944841245
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97     43126
#            1       1.00      0.41      0.58      4337
#
#     accuracy                           0.95     47463
#    macro avg       0.97      0.71      0.78     47463
# weighted avg       0.95      0.95      0.94     47463

# %%
preds_prob = vc.predict_proba(X_test)

# %%
cm=confusion_matrix(y_test, preds)
sns.heatmap(cm, annot=True,fmt="d")
experiment.log_figure(figure_name='Confusion Matrix', step=None)
# Out:
# {'web': 'https://www.comet.com/api/image/download?imageId=8d58c00f990d42039a2516e37de3d96f&experimentKey=78e64bfdfe2542b3972670db94f52bf2',
#  'api': 'https://www.comet.com/api/rest/v1/image/get-image?imageId=8d58c00f990d42039a2516e37de3d96f&experimentKey=78e64bfdfe2542b3972670db94f52bf2',
#  'imageId': '8d58c00f990d42039a2516e37de3d96f'}

# %%
metrics = {"accuracy": accuracy_score(y_test, preds), "f1": f1_score(y_test, preds), "recall": recall_score(y_test, preds), "precision": precision_score(y_test, preds)}
parameter = {
    "model_type": 'Voting Classifier',
    "param_grid": str(vc.get_params()),
}
experiment.log_parameters(parameter)
experiment.log_metrics(metrics)
# Out:
# COMET WARNING: truncated string; too long: '{'estimators': [('random_forest', Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('Numerical_transform',
#                                                   Pipeline(steps=[('Impt',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x172fd6110>),
#                                                  ('Categorical_transform',
#                                                   Pipeline(steps=[('Impt',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                   unknown_value=-1))]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x172fd6090>)])),
#                 ('feature_select', RFECV(estimator=LinearRegression())),
#                 ('classifier',
#                  RandomForestClassifier(max_depth=20, max_features='log2',
#                                         min_samples_split=4,
#                                         random_state=42))])), ('random_forest_balanced', Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('Numerical_transform',
#                                                   Pipeline(steps=[('Impt',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x172fd5b90>),
#                                                  ('Categorical_transform',
#                                                   Pipeline(steps=[('Impt',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                   unknown_value=-1))]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x172fd5b50>)])),
#                 ('feature_select', RFECV(estimator=LinearRegression())),
#                 ('classifier',
#                  RandomForestClassifier(max_depth=60, max_features='log2',
#                                         n_estimators=80, random_state=42))])), ('cat_boost_clf', Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('Numerical_transform',
#                                                   Pipeline(steps=[('Impt',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x172fd5590>),
#                                                  ('Categorical_transform',
#                                                   Pipeline(steps=[('Impt',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                   unknown_value=-1))]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x172fd5510>)])),
#                 ('feature_select', RFECV(estimator=LinearRegression())),
#                 ('classifier',
#                  <catboost.core.CatBoostClassifier object at 0x172fd57d0>)])), ('mlp', Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('Numerical_transform',
#                                                   Pipeline(steps=[('Impt',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x172fd6590>),
#                                                  ('Categorical_transform',
#                                                   Pipeline(steps=[('Impt',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                   unknown_value=-1))]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x172fd6510>)])),
#                 ('feature_select',
#                  SelectFromModel(estimator=LinearSVC(C=0.1, dual='auto'))),
#                 ('classifier',
#                  MLPClassifier(activation='tanh', alpha=0.01,
#                                early_stopping=True,
#                                hidden_layer_sizes=(50, 100, 100, 50),
#                                random_state=42))])), ('KNN', Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('Numerical_transform',
#                                                   Pipeline(steps=[('Impt',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x172f20d50>),
#                                                  ('Categorical_transform',
#                                                   Pipeline(steps=[('Impt',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                   unknown_value=-1))]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x172fd6810>)])),
#                 ('feature_select', RFECV(estimator=LinearRegression())),
#                 ('classifier',
#                  KNeighborsClassifier(metric='euclidean', n_neighbors=11))]))], 'flatten_transform': True, 'n_jobs': None, 'verbose': False, 'voting': 'soft', 'weights': None, 'random_forest': Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('Numerical_transform',
#                                                   Pipeline(steps=[('Impt',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x172fd6110>),
#                                                  ('Categorical_transform',
#                                                   Pipeline(steps=[('Impt',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                   unknown_value=-1))]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x172fd6090>)])),
#                 ('feature_select', RFECV(estimator=LinearRegression())),
#                 ('classifier',
#                  RandomForestClassifier(max_depth=20, max_features='log2',
#                                         min_samples_split=4,
#                                         random_state=42))]), 'random_forest_balanced': Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('Numerical_transform',
#                                                   Pipeline(steps=[('Impt',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x172fd5b90>),
#                                                  ('Categorical_transform',
#                                                   Pipeline(steps=[('Impt',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                   unknown_value=-1))]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x172fd5b50>)])),
#                 ('feature_select', RFECV(estimator=LinearRegression())),
#                 ('classifier',
#                  RandomForestClassifier(max_depth=60, max_features='log2',
#                                         n_estimators=80, random_state=42))]), 'cat_boost_clf': Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('Numerical_transform',
#                                                   Pipeline(steps=[('Impt',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x172fd5590>),
#                                                  ('Categorical_transform',
#                                                   Pipeline(steps=[('Impt',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                   unknown_value=-1))]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x172fd5510>)])),
#                 ('feature_select', RFECV(estimator=LinearRegression())),
#                 ('classifier',
#                  <catboost.core.CatBoostClassifier object at 0x172fd57d0>)]), 'mlp': Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('Numerical_transform',
#                                                   Pipeline(steps=[('Impt',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x172fd6590>),
#                                                  ('Categorical_transform',
#                                                   Pipeline(steps=[('Impt',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                   unknown_value=-1))]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x172fd6510>)])),
#                 ('feature_select',
#                  SelectFromModel(estimator=LinearSVC(C=0.1, dual='auto'))),
#                 ('classifier',
#                  MLPClassifier(activation='tanh', alpha=0.01,
#                                early_stopping=True,
#                                hidden_layer_sizes=(50, 100, 100, 50),
#                                random_state=42))]), 'KNN': Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('Numerical_transform',
#                                                   Pipeline(steps=[('Impt',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x172f20d50>),
#                                                  ('Categorical_transform',
#                                                   Pipeline(steps=[('Impt',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                   unknown_value=-1))]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x172fd6810>)])),
#                 ('feature_select', RFECV(estimator=LinearRegression())),
#                 ('classifier',
#                  KNeighborsClassifier(metric='euclidean', n_neighbors=11))]), 'random_forest__memory': None, 'random_forest__steps': [('preprocessor', ColumnTransformer(transformers=[('Numerical_transform',
#                                  Pipeline(steps=[('Impt', SimpleImputer()),
#                                                  ('scaler', StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x172fd6110>),
#                                 ('Categorical_transform',
#                                  Pipeline(steps=[('Impt',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('encoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x172fd6090>)])), ('feature_select', RFECV(estimator=LinearRegression())), ('classifier', RandomForestClassifier(max_depth=20, max_features='log2', min_samples_split=4,
#                        random_state=42))], 'random_forest__verbose': False, 'random_forest__preprocessor': ColumnTransformer(transformers=[('Numerical_transform',
#                                  Pipeline(steps=[('Impt', SimpleImputer()),
#                                                  ('scaler', StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x172fd6110>),
#                                 ('Categorical_transform',
#                                  Pipeline(steps=[('Impt',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('encoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x172fd6090>)]), 'random_forest__feature_select': RFECV(estimator=LinearRegression()), 'random_forest__classifier': RandomForestClassifier(max_depth=20, max_features='log2', min_samples_split=4,
#                        random_state=42), 'random_forest__preprocessor__n_jobs': None, 'random_forest__preprocessor__remainder': 'drop', 'random_forest__preprocessor__sparse_threshold': 0.3, 'random_forest__preprocessor__transformer_weights': None, 'random_forest__preprocessor__transformers': [('Numerical_transform', Pipeline(steps=[('Impt', SimpleImputer()), ('scaler', StandardScaler())]), <sklearn.compose._column_transformer.make_column_selector object at 0x172fd6110>), ('Categorical_transform', Pipeline(steps=[('Impt', SimpleImputer(strategy='most_frequent')),
#                 ('encoder',
#                  OrdinalEncoder(handle_unknown='use_encoded_value',
#                                 unknown_value=-1))]), <sklearn.compose._column_transformer.make_column_selector object at 0x172fd6090>)], 'random_forest__preprocessor__verbose': False, 'random_forest__preprocessor__verbose_feature_names_out': True, 'random_forest__preprocessor__Numerical_transform': Pipeline(steps=[('Impt', SimpleImputer()), ('scaler', StandardScaler())]), 'random_forest__preprocessor__Categorical_transform': Pipeline(steps=[('Impt', SimpleImputer(strategy='most_frequent')),
#                 ('encoder',
#                  OrdinalEncoder(handle_unknown='use_encoded_value',
#                                 unknown_value=-1))]), 'random_forest__preprocessor__Numerical_transform__memory': None, 'random_forest__preprocessor__Numerical_transform__steps': [('Impt', SimpleImputer()), ('scaler', StandardScaler())], 'random_forest__preprocessor__Numerical_transform__verbose': False, 'random_forest__preprocessor__Numerical_transform__Impt': SimpleImputer(), 'random_forest__preprocessor__Numerical_transform__scaler': StandardScaler(), 'random_forest__preprocessor__Numerical_transform__Impt__add_indicator': False, 'random_forest__preprocessor__Numerical_transform__Impt__copy': True, 'random_forest__preprocessor__Numerical_transform__Impt__fill_value': None, 'random_forest__preprocessor__Numerical_transform__Impt__keep_empty_features': False, 'random_forest__preprocessor__Numerical_transform__Impt__missing_values': nan, 'random_forest__preprocessor__Numerical_transform__Impt__strategy': 'mean', 'random_forest__preprocessor__Numerical_transform__scaler__copy': True, 'random_forest__preprocessor__Numerical_transform__scaler__with_mean': True, 'random_forest__preprocessor__Numerical_transform__scaler__with_std': True, 'random_forest__preprocessor__Categorical_transform__memory': None, 'random_forest__preprocessor__Categorical_transform__steps': [('Impt', SimpleImputer(strategy='most_frequent')), ('encoder', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1))], 'random_forest__preprocessor__Categorical_transform__verbose': False, 'random_forest__preprocessor__Categorical_transform__Impt': SimpleImputer(strategy='most_frequent'), 'random_forest__preprocessor__Categorical_transform__encoder': OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1), 'random_forest__preprocessor__Categorical_transform__Impt__add_indicator': False, 'random_forest__preprocessor__Categorical_transform__Impt__copy': True, 'random_forest__preprocessor__Categorical_transform__Impt__fill_value': None, 'random_forest__preprocessor__Categorical_transform__Impt__keep_empty_features': False, 'random_forest__preprocessor__Categorical_transform__Impt__missing_values': nan, 'random_forest__preprocessor__Categorical_transform__Impt__strategy': 'most_frequent', 'random_forest__preprocessor__Categorical_transform__encoder__categories': 'auto', 'random_forest__preprocessor__Categorical_transform__encoder__dtype': <class 'numpy.float64'>, 'random_forest__preprocessor__Categorical_transform__encoder__encoded_missing_value': nan, 'random_forest__preprocessor__Categorical_transform__encoder__handle_unknown': 'use_encoded_value', 'random_forest__preprocessor__Categorical_transform__encoder__max_categories': None, 'random_forest__preprocessor__Categorical_transform__encoder__min_frequency': None, 'random_forest__preprocessor__Categorical_transform__encoder__unknown_value': -1, 'random_forest__feature_select__cv': None, 'random_forest__feature_select__estimator__copy_X': True, 'random_forest__feature_select__estimator__fit_intercept': True, 'random_forest__feature_select__estimator__n_jobs': None, 'random_forest__feature_select__estimator__positive': False, 'random_forest__feature_select__estimator': LinearRegression(), 'random_forest__feature_select__importance_getter': 'auto', 'random_forest__feature_select__min_features_to_select': 1, 'random_forest__feature_select__n_jobs': None, 'random_forest__feature_select__scoring': None, 'random_forest__feature_select__step': 1, 'random_forest__feature_select__verbose': 0, 'random_forest__classifier__bootstrap': True, 'random_forest__classifier__ccp_alpha': 0.0, 'random_forest__classifier__class_weight': None, 'random_forest__classifier__criterion': 'gini', 'random_forest__classifier__max_depth': 20, 'random_forest__classifier__max_features': 'log2', 'random_forest__classifier__max_leaf_nodes': None, 'random_forest__classifier__max_samples': None, 'random_forest__classifier__min_impurity_decrease': 0.0, 'random_forest__classifier__min_samples_leaf': 1, 'random_forest__classifier__min_ ...
#                                  Pipeline(steps=[('Impt', SimpleImputer()),
#                                                  ('scaler', StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x172fd5b90>),
#                                 ('Categorical_transform',
#                                  Pipeline(steps=[('Impt',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('encoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x172fd5b50>)])), ('feature_select', RFECV(estimator=LinearRegression())), ('classifier', RandomForestClassifier(max_depth=60, max_features='log2', n_estimators=80,
#                        random_state=42))], 'random_forest_balanced__verbose': False, 'random_forest_balanced__preprocessor': ColumnTransformer(transformers=[('Numerical_transform',
#                                  Pipeline(steps=[('Impt', SimpleImputer()),
#                                                  ('scaler', StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x172fd5b90>),
#                                 ('Categorical_transform',
#                                  Pipeline(steps=[('Impt',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('encoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x172fd5b50>)]), 'random_forest_balanced__feature_select': RFECV(estimator=LinearRegression()), 'random_forest_balanced__classifier': RandomForestClassifier(max_depth=60, max_features='log2', n_estimators=80,
#                        random_state=42), 'random_forest_balanced__preprocessor__n_jobs': None, 'random_forest_balanced__preprocessor__remainder': 'drop', 'random_forest_balanced__preprocessor__sparse_threshold': 0.3, 'random_forest_balanced__preprocessor__transformer_weights': None, 'random_forest_balanced__preprocessor__transformers': [('Numerical_transform', Pipeline(steps=[('Impt', SimpleImputer()), ('scaler', StandardScaler())]), <sklearn.compose._column_transformer.make_column_selector object at 0x172fd5b90>), ('Categorical_transform', Pipeline(steps=[('Impt', SimpleImputer(strategy='most_frequent')),
#                 ('encoder',
#                  OrdinalEncoder(handle_unknown='use_encoded_value',
#                                 unknown_value=-1))]), <sklearn.compose._column_transformer.make_column_selector object at 0x172fd5b50>)], 'random_forest_balanced__preprocessor__verbose': False, 'random_forest_balanced__preprocessor__verbose_feature_names_out': True, 'random_forest_balanced__preprocessor__Numerical_transform': Pipeline(steps=[('Impt', SimpleImputer()), ('scaler', StandardScaler())]), 'random_forest_balanced__preprocessor__Categorical_transform': Pipeline(steps=[('Impt', SimpleImputer(strategy='most_frequent')),
#                 ('encoder',
#                  OrdinalEncoder(handle_unknown='use_encoded_value',
#                                 unknown_value=-1))]), 'random_forest_balanced__preprocessor__Numerical_transform__memory': None, 'random_forest_balanced__preprocessor__Numerical_transform__steps': [('Impt', SimpleImputer()), ('scaler', StandardScaler())], 'random_forest_balanced__preprocessor__Numerical_transform__verbose': False, 'random_forest_balanced__preprocessor__Numerical_transform__Impt': SimpleImputer(), 'random_forest_balanced__preprocessor__Numerical_transform__scaler': StandardScaler(), 'random_forest_balanced__preprocessor__Numerical_transform__Impt__add_indicator': False, 'random_forest_balanced__preprocessor__Numerical_transform__Impt__copy': True, 'random_forest_balanced__preprocessor__Numerical_transform__Impt__fill_value': None, 'random_forest_balanced__preprocessor__Numerical_transform__Impt__keep_empty_features': False, 'random_forest_balanced__preprocessor__Numerical_transform__Impt__missing_values': nan, 'random_forest_balanced__preprocessor__Numerical_transform__Impt__strategy': 'mean', 'random_forest_balanced__preprocessor__Numerical_transform__scaler__copy': True, 'random_forest_balanced__preprocessor__Numerical_transform__scaler__with_mean': True, 'random_forest_balanced__preprocessor__Numerical_transform__scaler__with_std': True, 'random_forest_balanced__preprocessor__Categorical_transform__memory': None, 'random_forest_balanced__preprocessor__Categorical_transform__steps': [('Impt', SimpleImputer(strategy='most_frequent')), ('encoder', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1))], 'random_forest_balanced__preprocessor__Categorical_transform__verbose': False, 'random_forest_balanced__preprocessor__Categorical_transform__Impt': SimpleImputer(strategy='most_frequent'), 'random_forest_balanced__preprocessor__Categorical_transform__encoder': OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1), 'random_forest_balanced__preprocessor__Categorical_transform__Impt__add_indicator': False, 'random_forest_balanced__preprocessor__Categorical_transform__Impt__copy': True, 'random_forest_balanced__preprocessor__Categorical_transform__Impt__fill_value': None, 'random_forest_balanced__preprocessor__Categorical_transform__Impt__keep_empty_features': False, 'random_forest_balanced__preprocessor__Categorical_transform__Impt__missing_values': nan, 'random_forest_balanced__preprocessor__Categorical_transform__Impt__strategy': 'most_frequent', 'random_forest_balanced__preprocessor__Categorical_transform__encoder__categories': 'auto', 'random_forest_balanced__preprocessor__Categorical_transform__encoder__dtype': <class 'numpy.float64'>, 'random_forest_balanced__preprocessor__Categorical_transform__encoder__encoded_missing_value': nan, 'random_forest_balanced__preprocessor__Categorical_transform__encoder__handle_unknown': 'use_encoded_value', 'random_forest_balanced__preprocessor__Categorical_transform__encoder__max_categories': None, 'random_forest_balanced__preprocessor__Categorical_transform__encoder__min_frequency': None, 'random_forest_balanced__preprocessor__Categorical_transform__encoder__unknown_value': -1, 'random_forest_balanced__feature_select__cv': None, 'random_forest_balanced__feature_select__estimator__copy_X': True, 'random_forest_balanced__feature_select__estimator__fit_intercept': True, 'random_forest_balanced__feature_select__estimator__n_jobs': None, 'random_forest_balanced__feature_select__estimator__positive': False, 'random_forest_balanced__feature_select__estimator': LinearRegression(), 'random_forest_balanced__feature_select__importance_getter': 'auto', 'random_forest_balanced__feature_select__min_features_to_select': 1, 'random_forest_balanced__feature_select__n_jobs': None, 'random_forest_balanced__feature_select__scoring': None, 'random_forest_balanced__feature_select__step': 1, 'random_forest_balanced__feature_select__verbose': 0, 'random_forest_balanced__classifier__bootstrap': True, 'random_forest_balanced__classifier__ccp_alpha': 0.0, 'random_forest_b ...
#                                  Pipeline(steps=[('Impt', SimpleImputer()),
#                                                  ('scaler', StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x172fd5590>),
#                                 ('Categorical_transform',
#                                  Pipeline(steps=[('Impt',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('encoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x172fd5510>)])), ('feature_select', RFECV(estimator=LinearRegression())), ('classifier', <catboost.core.CatBoostClassifier object at 0x172fd57d0>)], 'cat_boost_clf__verbose': False, 'cat_boost_clf__preprocessor': ColumnTransformer(transformers=[('Numerical_transform',
#                                  Pipeline(steps=[('Impt', SimpleImputer()),
#                                                  ('scaler', StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x172fd5590>),
#                                 ('Categorical_transform',
#                                  Pipeline(steps=[('Impt',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('encoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x172fd5510>)]), 'cat_boost_clf__feature_select': RFECV(estimator=LinearRegression()), 'cat_boost_clf__classifier': <catboost.core.CatBoostClassifier object at 0x172fd57d0>, 'cat_boost_clf__preprocessor__n_jobs': None, 'cat_boost_clf__preprocessor__remainder': 'drop', 'cat_boost_clf__preprocessor__sparse_threshold': 0.3, 'cat_boost_clf__preprocessor__transformer_weights': None, 'cat_boost_clf__preprocessor__transformers': [('Numerical_transform', Pipeline(steps=[('Impt', SimpleImputer()), ('scaler', StandardScaler())]), <sklearn.compose._column_transformer.make_column_selector object at 0x172fd5590>), ('Categorical_transform', Pipeline(steps=[('Impt', SimpleImputer(strategy='most_frequent')),
#                 ('encoder',
#                  OrdinalEncoder(handle_unknown='use_encoded_value',
#                                 unknown_value=-1))]), <sklearn.compose._column_transformer.make_column_selector object at 0x172fd5510>)], 'cat_boost_clf__preprocessor__verbose': False, 'cat_boost_clf__preprocessor__verbose_feature_names_out': True, 'cat_boost_clf__preprocessor__Numerical_transform': Pipeline(steps=[('Impt', SimpleImputer()), ('scaler', StandardScaler())]), 'cat_boost_clf__preprocessor__Categorical_transform': Pipeline(steps=[('Impt', SimpleImputer(strategy='most_frequent')),
#                 ('encoder',
#                  OrdinalEncoder(handle_unknown='use_encoded_value',
#                                 unknown_value=-1))]), 'cat_boost_clf__preprocessor__Numerical_transform__memory': None, 'cat_boost_clf__preprocessor__Numerical_transform__steps': [('Impt', SimpleImputer()), ('scaler', StandardScaler())], 'cat_boost_clf__preprocessor__Numerical_transform__verbose': False, 'cat_boost_clf__preprocessor__Numerical_transform__Impt': SimpleImputer(), 'cat_boost_clf__preprocessor__Numerical_transform__scaler': StandardScaler(), 'cat_boost_clf__preprocessor__Numerical_transform__Impt__add_indicator': False, 'cat_boost_clf__preprocessor__Numerical_transform__Impt__copy': True, 'cat_boost_clf__preprocessor__Numerical_transform__Impt__fill_value': None, 'cat_boost_clf__preprocessor__Numerical_transform__Impt__keep_empty_features': False, 'cat_boost_clf__preprocessor__Numerical_transform__Impt__missing_values': nan, 'cat_boost_clf__preprocessor__Numerical_transform__Impt__strategy': 'mean', 'cat_boost_clf__preprocessor__Numerical_transform__scaler__copy': True, 'cat_boost_clf__preprocessor__Numerical_transform__scaler__with_mean': True, 'cat_boost_clf__preprocessor__Numerical_transform__scaler__with_std': True, 'cat_boost_clf__preprocessor__Categorical_transform__memory': None, 'cat_boost_clf__preprocessor__Categorical_transform__steps': [('Impt', SimpleImputer(strategy='most_frequent')), ('encoder', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1))], 'cat_boost_clf__preprocessor__Categorical_transform__verbose': False, 'cat_boost_clf__preprocessor__Categorical_transform__Impt': SimpleImputer(strategy='most_frequent'), 'cat_boost_clf__preprocessor__Categorical_transform__encoder': OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1), 'cat_boost_clf__preprocessor__Categorical_transform__Impt__add_indicator': False, 'cat_boost_clf__preprocessor__Categorical_transform__Impt__copy': True, 'cat_boost_clf__preprocessor__Categorical_transform__Impt__fill_value': None, 'cat_boost_clf__preprocessor__Categorical_transform__Impt__keep_empty_features': False, 'cat_boost_clf__preprocessor__Categorical_transform__Impt__missing_values': nan, 'cat_boost_clf__preprocessor__Categorical_transform__Impt__strategy': 'most_frequent', 'cat_boost_clf__preprocessor__Categorical_transform__encoder__categories': 'auto', 'cat_boost_clf__preprocessor__Categorical_transform__encoder__dtype': <class 'numpy.float64'>, 'cat_boost_clf__preprocessor__Categorical_transform__encoder__encoded_missing_value': nan, 'cat_boost_clf__preprocessor__Categorical_transform__encoder__handle_unknown': 'use_encoded_value', 'cat_boost_clf__preprocessor__Categorical_transform__encoder__max_categories': None, 'cat_boost_clf__preprocessor__Categorical_transform__encoder__min_frequency': None, 'cat_boost_clf__preprocessor__Categorical_transform__encoder__unknown_value': -1, 'cat_boost_clf__feature_select__cv': None, 'cat_boost_clf__feature_select__estimator__copy_X': True, 'cat_boost_clf__feature_select__estimator__fit_intercept': True, 'cat_boost_clf__feature_select__estimator__n_jobs': None, 'cat_boost_clf__feature_select__estimator__positive': False, 'cat_boost_clf__feature_select__estimator': LinearRegression(), 'cat_boost_clf__feature_select__importance_getter': 'auto', 'cat_boost_clf__feature_select__min_features_to_select': 1, 'cat_boost_clf__feature_select__n_jobs': None, 'cat_boost_clf__feature_select__scoring': None, 'cat_boost_clf__feature_select__step': 1, 'cat_boost_clf__feature_select__verbose': 0, 'cat_boost_clf__classifier__learning_rate': 0.1, 'cat_boost_clf__classifier__random_seed': 42, 'cat_boost_clf__classifier__use_best_model': False, 'cat_boost_clf__classifier__logging_level': 'Silent', 'cat_boost_clf__classifier__eval_metric': 'Accuracy', 'cat_boost_clf__classifier__n_estimators': 500, 'mlp__memory': None, 'mlp__steps': [('preprocessor', ColumnTransformer(transformers=[('Numerical_transform',
#                                  Pipeline(steps=[('Impt', SimpleImputer()),
#                                                  ('scaler', StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x172fd6590>),
#                                 ('Categorical_transform',
#                                  Pipeline(steps=[('Impt',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('encoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x172fd6510>)])), ('feature_select', SelectFromModel(estimator=LinearSVC(C=0.1, dual='auto'))), ('classifier', MLPClassifier(activation='tanh', alpha=0.01, early_stopping=True,
#               hidden_layer_sizes=(50, 100, 100, 50), random_state=42))], 'mlp__verbose': False, 'mlp__preprocessor': ColumnTransformer(transformers=[('Numerical_transform',
#                                  Pipeline(steps=[('Impt', SimpleImputer()),
#                                                  ('scaler', StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x172fd6590>),
#                                 ('Categorical_transform',
#                                  Pipeline(steps=[('Impt',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('encoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x172fd6510>)]), 'mlp__feature_select': SelectFromModel(estimator=LinearSVC(C=0.1, dual='auto')), 'mlp__classifier': MLPClassifier(activation='tanh', alpha=0.01, early_stopping=True,
#               hidden_layer_sizes=(50, 100, 100, 50), random_state=42), 'mlp__preprocessor__n_jobs': None, 'mlp__preprocessor__remainder': 'drop', 'mlp__preprocessor__sparse_threshold': 0.3, 'mlp__preprocessor__transformer_weights': None, 'mlp__preprocessor__transformers': [('Numerical_transform', Pipeline(steps=[('Impt', SimpleImputer()), ('scaler', StandardScaler())]), <sklearn.compose._column_transformer.make_column_selector object at 0x172fd6590>), ('Categorical_transform', Pipeline(steps=[('Impt', SimpleImputer(strategy='most_frequent')),
#                 ('encoder',
#                  OrdinalEncoder(handle_unknown='use_encoded_value',
#                                 unknown_value=-1))]), <sklearn.compose._column_transformer.make_column_selector object at 0x172fd6510>)], 'mlp__preprocessor__verbose': False, 'mlp__preprocessor__verbose_feature_names_out': True, 'mlp__preprocessor__Numerical_transform': Pipeline(steps=[('Impt', SimpleImputer()), ('scaler', StandardScaler())]), 'mlp__preprocessor__Categorical_transform': Pipeline(steps=[('Impt', SimpleImputer(strategy='most_frequent')),
#                 ('encoder',
#                  OrdinalEncoder(handle_unknown='use_encoded_value',
#                                 unknown_value=-1))]), 'mlp__preprocessor__Numerical_transform__memory': None, 'mlp__preprocessor__Numerical_transform__steps': [('Impt', SimpleImputer()), ('scaler', StandardScaler())], 'mlp__preprocessor__Numerical_transform__verbose': False, 'mlp__preprocessor__Numerical_transform__Impt': SimpleImputer(), 'mlp__preprocessor__Numerical_transform__scaler': StandardScaler(), 'mlp__preprocessor__Numerical_transform__Impt__add_indicator': False, 'mlp__preprocessor__Numerical_transform__Impt__copy': True, 'mlp__preprocessor__Numerical_transform__Impt__fill_value': None, 'mlp__preprocessor__Numerical_transform__Impt__keep_empty_features': False, 'mlp__preprocessor__Numerical_transform__Impt__missing_values': nan, 'mlp__preprocessor__Numerical_transform__Impt__strategy': 'mean', 'mlp__preprocessor__Numerical_transform__scaler__copy': True, 'mlp__preprocessor__Numerical_transform__scaler__with_mean': True, 'mlp__preprocessor__Numerical_transform__scaler__with_std': True, 'mlp__preprocessor__Categorical_transform__memory': None, 'mlp__preprocessor__Categorical_transform__steps': [('Impt', SimpleImputer(strategy='most_frequent')), ('encoder', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1))], 'mlp__preprocessor__Categorical_transform__verbose': False, 'mlp__preprocessor__Categorical_transform__Impt': SimpleImputer(strategy='most_frequent'), 'mlp__preprocessor__Categorical_transform__encoder': OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1), 'mlp__preprocessor__Categorical_transform__Impt__add_indicator': False, 'mlp__preprocessor__Categorical_transform__Impt__copy': True, 'mlp__preprocessor__Categorical_transform__Impt__fill_value': None, 'mlp__preprocessor__Categorical_transform__Impt__keep_empty_features': False, 'mlp__preprocessor__Categorical_transform__Impt__missing_values': nan, 'mlp__preprocessor__Categorical_transform__Impt__strategy': 'most_frequent', 'mlp__preprocessor__Categorical_transform__encoder__categories': 'auto', 'mlp__preprocessor__Categorical_transform__encoder__dtype': <class 'numpy.float64'>, 'mlp__preprocessor__Categorical_transform__encoder__encoded_missing_value': nan, 'mlp__preprocessor__Categorical_transform__encoder__handle_unknown': 'use_encoded_value', 'mlp__preprocessor__Categorical_transform__encoder__max_categories': None, 'mlp__preprocessor__Categorical_transform__encoder__min_frequency': None, 'mlp__preprocessor__Categorical_transform__encoder__unknown_value': -1, 'mlp__feature_select__estimator__C': 0.1, 'mlp__feature_select__estimator__class_weight': None, 'mlp__feature_select__estimator__dual': 'auto', 'mlp__feature_select__estimator__fit_intercept': True, 'mlp__feature_select__estimator__intercept_scaling': 1, 'mlp__feature_select__estimator__loss': 'squared_hinge', 'mlp__feature_select__estimator__max_iter': 1000, 'mlp__feature_select__estimator__multi_class': 'ovr', 'mlp__feature_select__estimator__penalty': 'l2', 'mlp__feature_select__estimator__random_state': None, 'mlp__feature_select__estimator__tol': 0.0001, 'mlp__feature_select__estimator__verbose': 0, 'mlp__feature_select__estimator': LinearSVC(C=0.1, dual='auto'), 'mlp__feature_select__importance_getter': 'auto', 'mlp__feature_select__max_features': None, 'mlp__feature_select__norm_order': 1, 'mlp__feature_select__prefit': False, 'mlp__feature_select__threshold': None, 'mlp__classifier__activation': 'tanh', 'mlp__classifier__alpha': 0.01, 'mlp__classifier__batch_size': 'auto', 'mlp__classifier__beta_1': 0.9, 'mlp__classifier__beta_2': 0.999, 'mlp__classifier__early_stopping': True, 'mlp__classifier__epsilon': 1e-08, 'mlp__classifier__hidden_layer_sizes': (50, 100, 100, 50), 'mlp__classifier__learning_rate': 'constant', 'mlp__classifier__learning_rate_init': 0.001, 'mlp__classifier__max_fun': 15000, 'mlp__classifier__max_iter': 200, 'mlp__classifier__momentum': 0.9, 'mlp__classifier__n_iter_no_change': 10, 'mlp__classifier__nesterovs_momentum': True, 'mlp__classifi ...
#                                  Pipeline(steps=[('Impt', SimpleImputer()),
#                                                  ('scaler', StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x172f20d50>),
#                                 ('Categorical_transform',
#                                  Pipeline(steps=[('Impt',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('encoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x172fd6810>)])), ('feature_select', RFECV(estimator=LinearRegression())), ('classifier', KNeighborsClassifier(metric='euclidean', n_neighbors=11))], 'KNN__verbose': False, 'KNN__preprocessor': ColumnTransformer(transformers=[('Numerical_transform',
#                                  Pipeline(steps=[('Impt', SimpleImputer()),
#                                                  ('scaler', StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x172f20d50>),
#                                 ('Categorical_transform',
#                                  Pipeline(steps=[('Impt',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('encoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x172fd6810>)]), 'KNN__feature_select': RFECV(estimator=LinearRegression()), 'KNN__classifier': KNeighborsClassifier(metric='euclidean', n_neighbors=11), 'KNN__preprocessor__n_jobs': None, 'KNN__preprocessor__remainder': 'drop', 'KNN__preprocessor__sparse_threshold': 0.3, 'KNN__preprocessor__transformer_weights': None, 'KNN__preprocessor__transformers': [('Numerical_transform', Pipeline(steps=[('Impt', SimpleImputer()), ('scaler', StandardScaler())]), <sklearn.compose._column_transformer.make_column_selector object at 0x172f20d50>), ('Categorical_transform', Pipeline(steps=[('Impt', SimpleImputer(strategy='most_frequent')),
#                 ('encoder',
#                  OrdinalEncoder(handle_unknown='use_encoded_value',
#                                 unknown_value=-1))]), <sklearn.compose._column_transformer.make_column_selector object at 0x172fd6810>)], 'KNN__preprocessor__verbose': False, 'KNN__preprocessor__verbose_feature_names_out': True, 'KNN__preprocessor__Numerical_transform': Pipeline(steps=[('Impt', SimpleImputer()), ('scaler', StandardScaler())]), 'KNN__preprocessor__Categorical_transform': Pipeline(steps=[('Impt', SimpleImputer(strategy='most_frequent')),
#                 ('encoder',
#                  OrdinalEncoder(handle_unknown='use_encoded_value',
#                                 unknown_value=-1))]), 'KNN__preprocessor__Numerical_transform__memory': None, 'KNN__preprocessor__Numerical_transform__steps': [('Impt', SimpleImputer()), ('scaler', StandardScaler())], 'KNN__preprocessor__Numerical_transform__verbose': False, 'KNN__preprocessor__Numerical_transform__Impt': SimpleImputer(), 'KNN__preprocessor__Numerical_transform__scaler': StandardScaler(), 'KNN__preprocessor__Numerical_transform__Impt__add_indicator': False, 'KNN__preprocessor__Numerical_transform__Impt__copy': True, 'KNN__preprocessor__Numerical_transform__Impt__fill_value': None, 'KNN__preprocessor__Numerical_transform__Impt__keep_empty_features': False, 'KNN__preprocessor__Numerical_transform__Impt__missing_values': nan, 'KNN__preprocessor__Numerical_transform__Impt__strategy': 'mean', 'KNN__preprocessor__Numerical_transform__scaler__copy': True, 'KNN__preprocessor__Numerical_transform__scaler__with_mean': True, 'KNN__preprocessor__Numerical_transform__scaler__with_std': True, 'KNN__preprocessor__Categorical_transform__memory': None, 'KNN__preprocessor__Categorical_transform__steps': [('Impt', SimpleImputer(strategy='most_frequent')), ('encoder', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1))], 'KNN__preprocessor__Categorical_transform__verbose': False, 'KNN__preprocessor__Categorical_transform__Impt': SimpleImputer(strategy='most_frequent'), 'KNN__preprocessor__Categorical_transform__encoder': OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1), 'KNN__preprocessor__Categorical_transform__Impt__add_indicator': False, 'KNN__preprocessor__Categorical_transform__Impt__copy': True, 'KNN__preprocessor__Categorical_transform__Impt__fill_value': None, 'KNN__preprocessor__Categorical_transform__Impt__keep_empty_features': False, 'KNN__preprocessor__Categorical_transform__Impt__missing_values': nan, 'KNN__preprocessor__Categorical_transform__Impt__strategy': 'most_frequent', 'KNN__preprocessor__Categorical_transform__encoder__categories': 'auto', 'KNN__preprocessor__Categorical_transform__encoder__dtype': <class 'numpy.float64'>, 'KNN__preprocessor__Categorical_transform__encoder__encoded_missing_value': nan, 'KNN__preprocessor__Categorical_transform__encoder__handle_unknown': 'use_encoded_value', 'KNN__preprocessor__Categorical_transform__encoder__max_categories': None, 'KNN__preprocessor__Categorical_transform__encoder__min_frequency': None, 'KNN__preprocessor__Categorical_transform__encoder__unknown_value': -1, 'KNN__feature_select__cv': None, 'KNN__feature_select__estimator__copy_X': True, 'KNN__feature_select__estimator__fit_intercept': True, 'KNN__feature_select__estimator__n_jobs': None, 'KNN__feature_select__estimator__positive': False, 'KNN__feature_select__estimator': LinearRegression(), 'KNN__feature_select__importance_getter': 'auto', 'KNN__feature_select__min_features_to_select': 1, 'KNN__feature_select__n_jobs': None, 'KNN__feature_select__scoring': None, 'KNN__feature_select__step': 1, 'KNN__feature_select__verbose': 0, 'KNN__classifier__algorithm': 'auto', 'KNN__classifier__leaf_size': 30, 'KNN__classifier__metric': 'euclidean', 'KNN__classifier__metric_params': None, 'KNN__classifier__n_jobs': None, 'KNN__classifier__n_neighbors': 11, 'KNN__classifier__p': 2, 'KNN__classifier__weights': 'uniform'}'...

# %% [markdown]
# ### Prec-Recall Curve

# %%
other_ml_models.plot_precision_recall(model=vc, X_test=X_test, y_test=y_test, experiment=experiment)

# %% [markdown]
# ### ROC Curve

# %%
plt.figure(figsize=(10, 6))
line_width = 2

false_positive_rate, true_positive_rate, _ = roc_curve(y_test.ravel(),preds_prob[:,1].ravel())
area_under_curve = auc(false_positive_rate, true_positive_rate)
plt.plot(false_positive_rate, true_positive_rate, lw=line_width, label=f"Model Voting Ensemble - AUC: {area_under_curve:.2f}")

plt.plot([0, 1], [0, 1], color="grey", lw=line_width, linestyle='--', label="Baseline (Random)")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve Comparison")
plt.legend(loc="lower right")
experiment.log_figure(figure_name='ROC-AUC', step=None)
plt.show()

# %% [markdown]
# ### Goal Rate Plot

# %%
bins = list(np.arange(0, 105,  5))
bin_centers = list(np.arange(2.5, 100,  5.0))
df_prob = pd.DataFrame(list(zip(preds ,y_test ,preds_prob[:,1]*100)), columns = ['goal_pred', 'goal','goal_probability'])
df_prob['shot'] = 1
sum_goal = df_prob['goal'].sum()
df_prob['percentile'] = df_prob['goal_probability'].rank(pct=True) * 100
df_prob['goal_perc_bins'] = pd.cut(df_prob['percentile'], bins, labels = bin_centers)
df_prob_bined = df_prob[['goal_perc_bins', 'shot', 'goal' ]].groupby(['goal_perc_bins']).sum().reset_index()
df_prob_bined['goal_rate'] = (df_prob_bined['goal']/df_prob_bined['shot'])
df_prob_bined['goal_cum'] = (df_prob_bined['goal']/sum_goal)
df_prob_bined['goal_cumsum'] = 1-df_prob_bined['goal_cum'].cumsum()

# %%
other_ml_models.generate_goal_rate_plot("Voting Ensemble Classifier", df_prob_bined, experiment)

# %% [markdown]
# ### Cumulative Goal Analysis

# %%
other_ml_models.visualize_cumulative_goals("Voting Ensemble Classifier", df_prob_bined, experiment)

# %% [markdown]
# ### Calibration curve

# %%
other_ml_models.plot_calibration_curve(y_test, preds_prob, experiment)

# %% [markdown]
# ### Save Model

# %%
import pickle

# %%
if not os.path.exists('models/'):
    os.mkdir('models/')
    
pickle.dump(vc, open('models/ensemble.sav', 'wb'))
experiment.log_model("Voting Ensemble Clf", 'models/ensemble.sav')
# Out:
# {'web': 'https://www.comet.com/api/asset/download?assetId=68e8be8b4c374a0cb3d7116d03fb27c5&experimentKey=78e64bfdfe2542b3972670db94f52bf2',
#  'api': 'https://www.comet.com/api/rest/v2/experiment/asset/get-asset?assetId=68e8be8b4c374a0cb3d7116d03fb27c5&experimentKey=78e64bfdfe2542b3972670db94f52bf2',
#  'assetId': '68e8be8b4c374a0cb3d7116d03fb27c5'}

# %%
experiment.end()
# Out:
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.com/mahmoodhegazy/nhl-data-science/78e64bfdfe2542b3972670db94f52bf2
# COMET INFO:   Metrics:
# COMET INFO:     accuracy  : 0.9461685944841245
# COMET INFO:     f1        : 0.5835370823145885
# COMET INFO:     precision : 0.9955506117908788
# COMET INFO:     recall    : 0.4127276919529629
# COMET INFO:   Parameters:
# COMET INFO:     model_type : Voting Classifier
# COMET INFO:     param_grid : {'estimators': [('random_forest', Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('Numerical_transform',
#                                                   Pipeline(steps=[('Impt',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x172fd6110>),
#                                                  ('Categorical_transform',
#                                                   Pipeline(steps=[('Impt',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                       [truncated]
# COMET INFO:   Uploads:
# COMET INFO:     conda-environment-definition : 1
# COMET INFO:     conda-info                   : 1
# COMET INFO:     conda-specification          : 1
# COMET INFO:     environment details          : 1
# COMET INFO:     figures                      : 6
# COMET INFO:     filename                     : 1
# COMET INFO:     git metadata                 : 1
# COMET INFO:     git-patch (uncompressed)     : 1 (1.39 MB)
# COMET INFO:     installed packages           : 1
# COMET INFO:     model-element                : 1 (276.14 MB)
# COMET INFO:     notebook                     : 1
# COMET INFO:     source_code                  : 1
# COMET INFO:
# COMET WARNING: To get all data logged automatically, import comet_ml before the following modules: sklearn.
# COMET INFO: Please wait for assets to finish uploading (timeout is 10800 seconds)
# COMET INFO: Still uploading 1 file(s), remaining 249.04 MB/276.14 MB
# COMET INFO: Still uploading 1 asset(s), remaining 150.23 MB/276.14 MB, Throughput 6.56 MB/s, ETA ~23s
# COMET INFO: Still uploading 1 asset(s), remaining 55.82 MB/276.14 MB, Throughput 6.27 MB/s, ETA ~9s
